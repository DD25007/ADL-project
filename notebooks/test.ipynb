# %%
# !kaggle datasets download -d aryashah2k/breast-ultrasound-images-dataset -p ../data --unzip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/aryashah2k/breast-ultrasound-images-dataset
# License(s): CC0-1.0
# Downloading breast-ultrasound-images-dataset.zip to ../data
#   0%|                                                | 0.00/195M [00:00<?, ?B/s]
# 100%|████████████████████████████████████████| 195M/195M [00:00<00:00, 3.68GB/s]

# %%
from datasets import load_dataset

ds = load_dataset("Amss007/ultrasound_dataset_v3_1", cache_dir="../data")
print(ds)
# Out:
# Generating train split:   0%|          | 0/3985 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'conditioning_image', 'caption'],
#         num_rows: 3985
#     })
# })

# %%
import matplotlib.pyplot as plt

example = ds["train"][0]
image = example["image"]  # PIL Image
conditioning_image = example["conditioning_image"]  # PIL Image or None
caption = example["caption"]  # String

fig, axs = plt.subplots(1, 2, figsize=(10, 5))

axs[0].imshow(image)
axs[0].set_title("Image")
axs[0].axis("off")

if conditioning_image is not None:
    axs[1].imshow(conditioning_image)
    axs[1].set_title("Conditioning Image")
else:
    axs[1].set_visible(False)

plt.suptitle(caption)
plt.tight_layout()
